# %%
# Plot appearance
#
# Runs notebooks from inside another Notebook
# %run MatplotlibLecture(Concepts).ipynb
#
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
# Can also use Hex Code for colors
ax.plot(x, y, color="blue", label="Blue", linewidth=5, marker='-')
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     267             try:
# --> 268                 Path(marker)
#     269                 self._marker_function = self._set_vertices
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     131         """
# --> 132         vertices = _to_unmasked_float_array(vertices)
#     133         if (vertices.ndim != 2) or (vertices.shape[1] != 2):
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    2051     else:
# -> 2052         return np.asarray(x, float)
#    2053
#
# /anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     500     """
# ...
